# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
phones = pd.read_csv('phones.csv') #? Reads the csv file obviously :)
phones.head(5) #! Prints first 5 rows of a dataset.
phones.tail(5) #! Prints the last 5 rows of a dataset.
# Out:
#       brand             model               colour  original_price  \
# 831  REALME  REALME GT NEO 2              NEO Blue           38999
# 832  REALME  REALME GT NEO 2             NEO Black           38999
# 833  REALME  REALME GT NEO 2             NEO Black           34999
# 834  REALME   REALME X50 PRO              Rust Red           17999
# 835  XIAOMI      POCO M2 PRO   Two Shades of Black           17999
#
#      discounted_price  ratings  rating_count  reviews  memory  storage  \
# 831             35999      4.4          4430      628     NaN    256.0
# 832             35999      4.4          4430      628     NaN    256.0
# 833             31999      4.4         18194     2478     8.0    128.0
# 834             41999      4.4          8689     1232     8.0    128.0
# 835             17999      4.4        350744    33202     6.0     64.0
#
#                     processor               rear_camera      front_camera  \
# ...

# %%
phones.iloc[3] #! Prints the index's columns
# Out:
# brand                               XIAOMI
# model                          POCO M4 5G
# colour                         Power Black
# original_price                       15999
# discounted_price                     11999
# ratings                                4.2
# rating_count                         53448
# reviews                               4185
# memory                                 4.0
# storage                               64.0
# processor           Mediatek Dimensity 700
# rear_camera                    50MP + 2MP
# front_camera                           8MP
# display_size                         16.71
# battery_capacity                    5000.0
# battery_type               Lithium Polymer
# Name: 3, dtype: object

# %%
phones.columns #! Shows the columns in a data frame.
phones.shape #! Shows the size of the data frame.
# Out:
# (836, 16)

# %%
phones = pd.read_csv('phones.csv',chunksize=15) #? our file is so large it can't be read onc at a time so by setting chuncks it can be read\
for chunk in phones: #! a chunk has to be printed in a for loop
    print(chunk)
    break
# Out:
#       brand                 model           colour  original_price  \
# 0      VIVO          VIVO T1 44W        Starry Sky           19990
# 1     APPLE      APPLE IPHONE 11             White           48900
# 2      VIVO          VIVO T1 44W   Midnight Galaxy           20990
# 3    XIAOMI           POCO M4 5G       Power Black           15999
# 4    XIAOMI             REDMI 10   Caribbean Green           14999
# 5    XIAOMI           POCO M4 5G         Cool Blue           15999
# 6    XIAOMI             POCO C31       Shadow Gray           11999
# 7    XIAOMI           POCO M4 5G            Yellow           15999
# 8    XIAOMI             REDMI 10    Midnight Black           14999
# 9      VIVO          VIVO T1 44W   Midnight Galaxy           23990
# 10     VIVO          VIVO T1 44W        Starry Sky           20990
# 11  INFINIX  INFINIX HOT 20 PLAY      Racing Black           11999
# 12  INFINIX  INFINIX HOT 20 PLAY         Luna Blue           11999
# ...

# %%
phones = pd.read_csv('phones.csv') #? reads the file obviously :)
phones = phones[phones['original_price']<10000] #! this is a way filter the dataFrame
phones
# Out:
#       brand                model        colour  original_price  \
# 14   XIAOMI      REDMI 9I SPORT   Carbon Black            9999
# 21   REALME          REALME C30   Bamboo Green            9299
# 22   REALME          REALME C30      Lake Blue            8499
# 24   REALME          REALME C30      Lake Blue            9299
# 25   REALME          REALME C30    Denim Black            9299
# ..      ...                  ...           ...             ...
# 744    ITEL            ITEL A27   Crystal Blue            6999
# 745    ITEL            ITEL A27      Deep Grey            6999
# 770   TECNO       TECNO SPARK 9     Sky Mirror            9498
# 820    ITEL  ITEL VISION3 TURBO    Multi Green            8999
# 829   TECNO       TECNO SPARK 7   Spruce Green            8999
#
#      discounted_price  ratings  rating_count  reviews  memory  storage  \
# 14               7499      4.3        236239    13755     4.0     64.0
# ...

# %%
phones = phones[(phones['storage'] >= 64.0) & (phones['ratings']> 4.0)]
phones #! since it is a variable you can filter the filter too
# Out:
#         brand                  model             colour  original_price  \
# 14     XIAOMI        REDMI 9I SPORT        Carbon Black            9999
# 62     XIAOMI        REDMI 9I SPORT         Coral Green            9999
# 122    XIAOMI              REDMI 9I      Midnight Black            9999
# 150    XIAOMI        REDMI 9I SPORT       Metallic Blue            9999
# 222   INFINIX       INFINIX SMART 6     Light Sea Green            8999
# 250  MOTOROLA          MOTOROLA E13        Creamy White            9999
# 258   INFINIX       INFINIX SMART 6         Polar Black            8999
# 259   INFINIX       INFINIX SMART 6      Heart Of Ocean            8999
# 260   INFINIX       INFINIX SMART 6       Starry Purple            8999
# 271  MOTOROLA          MOTOROLA E13        Cosmic Black            9999
# 283  MOTOROLA          MOTOROLA E13        Aurora Green            9999
# 291    REALME       REALME C11 2021           Cool Grey            9999
# ...

# %%
phones.isnull() #! shows null values in the df
phones.isnull().sum() #! shows how many null values are in every column
# Out:
# brand                0
# model                0
# colour               0
# original_price       0
# discounted_price     0
# ratings              0
# rating_count         0
# reviews              0
# memory               0
# storage              0
# processor            1
# rear_camera          0
# front_camera         1
# display_size         0
# battery_capacity     0
# battery_type        13
# dtype: int64

# %%
phones.isnull().sum().sum() #! shows how many null values are in general
# Out:
# 15

# %%
phones.duplicated() #! Shows rows that are duplicated completely
# Out:
# 14     False
# 62     False
# 122    False
# 150    False
# 222    False
# 250    False
# 258    False
# 259    False
# 260    False
# 271    False
# 283    False
# 291    False
# 292    False
# 293    False
# 335    False
# 407    False
# 518    False
# 521    False
# 531    False
# 550    False
# 600    False
# 603    False
# 641    False
# 643    False
# 722    False
# dtype: bool

# %% [markdown]
# You can either drop thee missing values
# You can fill the missing values using relashionships found in the dataframe

# %%
phones = phones.drop_duplicates()

# %%
phones.duplicated().sum()
# Out:
# 0

# %%
phones = phones.dropna('battery_type')
# Out:
# C:\Users\yomus\AppData\Local\Temp\ipykernel_8688\2349425733.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.dropna will be keyword-only.
#   phones = phones.dropna(["battery_type"])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8688\2349425733.py in <module>
# ----> 1 phones = phones.dropna(["battery_type"])
#
# c:\Users\yomus\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# c:\Users\yomus\anaconda3\lib\site-packages\pandas\core\frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    5995         if isinstance(axis, (tuple, list)):
#    5996             # GH20987
# ...

# %%
phones.isnull().sum().sum() #! shows how many null values are in general
# Out:
# 0

# %%
phones
# Out:
#        brand                  model             colour  original_price  \
# 14    XIAOMI        REDMI 9I SPORT        Carbon Black            9999
# 62    XIAOMI        REDMI 9I SPORT         Coral Green            9999
# 122   XIAOMI              REDMI 9I      Midnight Black            9999
# 150   XIAOMI        REDMI 9I SPORT       Metallic Blue            9999
# 222  INFINIX       INFINIX SMART 6     Light Sea Green            8999
# 258  INFINIX       INFINIX SMART 6         Polar Black            8999
# 259  INFINIX       INFINIX SMART 6      Heart Of Ocean            8999
# 260  INFINIX       INFINIX SMART 6       Starry Purple            8999
# 293  INFINIX  INFINIX SMART 6 PLUS   Tranquil Sea Blue            9999
# 335  INFINIX  INFINIX SMART 6 PLUS       Miracle Black            9999
# 407  INFINIX  INFINIX SMART 6 PLUS      Crystal Violet            9999
# 550   XIAOMI              REDMI 9I            Sea Blue            9999
#
# ...

# %%
phones.shape
# Out:
# (12, 16)

# %%
phones.columns
# Out:
# Index(['brand', 'model', 'colour', 'original_price', 'discounted_price',
#        'ratings', 'rating_count', 'reviews', 'memory', 'storage', 'processor',
#        'rear_camera', 'front_camera', 'display_size', 'battery_capacity',
#        'battery_type'],
#       dtype='object')
